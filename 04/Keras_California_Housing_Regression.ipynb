# %% [markdown]
# # Copyright
#
# <PRE>
# Jelen Jupyter notebook a Budapesti Műszaki és Gazdaságtudományi Egyetemen tartott "Deep Learning a gyakorlatban Python és LUA alapon" tantárgy segédanyagaként készült.
# A tantárgy honlapja: http://smartlab.tmit.bme.hu/oktatas-deep-learning
# Deep Learning kutatás: http://smartlab.tmit.bme.hu/deep-learning
#
# A notebook bármely részének újra felhasználása, publikálása csak a szerzők írásos beleegyezése esetén megegengedett.
#
# 2019 (c) Gyires-Tóth Bálint (toth.b kukac tmit pont bme pont hu)
# </PRE>

# %% [markdown]
# # Regresszió mély tanulással

# %% [markdown]
# Ebben a notebookban a gépi tanulás egyik "Hello world"-jét fogjuk megismeri. Ehhez a Californa Housing Prices adatbázist fogjuk felhasználni.
#
# Az adatbázisról egy rövid leírást itt találunk:
# https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset
#
# Részletesebb leírást, elemzést itt:
# https://inria.github.io/scikit-learn-mooc/python_scripts/datasets_california_housing.html
#
# Következő lépésként importáljuk a szükséges modulokat és állítsunk be egy random seed-et:

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
import copy
import pandas as pd
from tensorflow.keras.optimizers import SGD
from sklearn.preprocessing import StandardScaler


np.random.seed(123)

# %% [markdown]
# Ezután töltsük le és töltsük be az adatokat, válasszuk szét a train-validation-test adathalmazokat és standardizáljuk a bemeneteket:

# %%
from sklearn.datasets import fetch_california_housing

california_housing = fetch_california_housing(as_frame=True)

# %%
california_housing.frame
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# 0        -122.23        4.526
# 1        -122.22        3.585
# 2        -122.24        3.521
# 3        -122.25        3.413
# 4        -122.25        3.422
# ...          ...          ...
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894
#
# [20640 rows x 9 columns]

# %%
dataset = california_housing.frame.values
test_split = 0.1
valid_split = 0.1

X = dataset[:,0:-1]
Y = dataset[:,-1]

v_index = int(X.shape[0]*(1-valid_split-test_split))
t_index = int(X.shape[0]*(1-test_split))

X_test = X[t_index:]
Y_test = Y[t_index:]
X_valid = X[v_index:t_index]
Y_valid = Y[v_index:t_index]
X = X[:v_index]
Y = Y[:v_index]

scaler = StandardScaler().fit(X)
X = scaler.transform(X)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %% [markdown]
# Ezt követően adjuk meg a callback függvényeket:

# %%
patience=15
early_stopping=EarlyStopping(patience=patience, verbose=1)
checkpointer=ModelCheckpoint(filepath='weights.keras', save_best_only=True, verbose=1)

# %% [markdown]
# És hozzuk létre a hálót és tanítsuk be:

# %%
model = Sequential()
model.add(Dense(units=200, input_dim=X.shape[1]))
model.add(Activation('sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='linear'))

sgd = SGD(learning_rate=1e-3, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mse', optimizer=sgd)
history=model.fit(X,Y,epochs=10000,
                  batch_size=16,
                  verbose=2,
                  validation_data=(X_valid, Y_valid),
                  callbacks=[checkpointer, early_stopping])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10000
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1: val_loss improved from inf to 1.10194, saving model to weights.keras
# 1032/1032 - 4s - 4ms/step - loss: 1.0758 - val_loss: 1.1019
# Epoch 2/10000
#
# Epoch 2: val_loss improved from 1.10194 to 1.04413, saving model to weights.keras
# 1032/1032 - 1s - 1ms/step - loss: 0.8687 - val_loss: 1.0441
# Epoch 3/10000
#
# Epoch 3: val_loss improved from 1.04413 to 0.87723, saving model to weights.keras
# 1032/1032 - 2s - 1ms/step - loss: 0.8110 - val_loss: 0.8772
# Epoch 4/10000
#
# Epoch 4: val_loss did not improve from 0.87723
# 1032/1032 - 1s - 1ms/step - loss: 0.7781 - val_loss: 0.9376
# Epoch 5/10000
#
# Epoch 5: val_loss improved from 0.87723 to 0.87202, saving model to weights.keras
# 1032/1032 - 1s - 1ms/step - loss: 0.7466 - val_loss: 0.8720
# Epoch 6/10000
#
# Epoch 6: val_loss improved from 0.87202 to 0.71020, saving model to weights.keras
# 1032/1032 - 2s - 2ms/step - loss: 0.7224 - val_loss: 0.7102
# Epoch 7/10000
#
# Epoch 7: val_loss did not improve from 0.71020
# 1032/1032 - 2s - 2ms/step - loss: 0.7187 - val_loss: 0.8053
# Epoch 8/10000
#
# Epoch 8: val_loss improved from 0.71020 to 0.60503, saving model to weights.keras
# 1032/1032 - 2s - 2ms/step - loss: 0.7040 - val_loss: 0.6050
# Epoch 9/10000
#
# Epoch 9: val_loss did not improve from 0.60503
# 1032/1032 - 3s - 2ms/step - loss: 0.6987 - val_loss: 0.9682
# Epoch 10/10000
#
# Epoch 10: val_loss did not improve from 0.60503
# 1032/1032 - 2s - 2ms/step - loss: 0.6849 - val_loss: 0.8657
# Epoch 11/10000
#
# Epoch 11: val_loss did not improve from 0.60503
# 1032/1032 - 3s - 3ms/step - loss: 0.6813 - val_loss: 0.7213
# Epoch 12/10000
#
# Epoch 12: val_loss did not improve from 0.60503
# 1032/1032 - 3s - 3ms/step - loss: 0.6741 - val_loss: 0.9095
# Epoch 13/10000
#
# Epoch 13: val_loss did not improve from 0.60503
# 1032/1032 - 2s - 2ms/step - loss: 0.6660 - val_loss: 0.6851
# Epoch 14/10000
#
# Epoch 14: val_loss did not improve from 0.60503
# 1032/1032 - 1s - 1ms/step - loss: 0.6568 - val_loss: 0.8136
# Epoch 15/10000
#
# Epoch 15: val_loss did not improve from 0.60503
# 1032/1032 - 2s - 2ms/step - loss: 0.6583 - val_loss: 0.7078
# Epoch 16/10000
#
# Epoch 16: val_loss did not improve from 0.60503
# 1032/1032 - 1s - 1ms/step - loss: 0.6565 - val_loss: 0.6176
# Epoch 17/10000
#
# Epoch 17: val_loss did not improve from 0.60503
# 1032/1032 - 1s - 1ms/step - loss: 0.6454 - val_loss: 0.6263
# Epoch 18/10000
#
# Epoch 18: val_loss did not improve from 0.60503
# 1032/1032 - 1s - 1ms/step - loss: 0.6382 - val_loss: 0.6634
# Epoch 19/10000
#
# Epoch 19: val_loss did not improve from 0.60503
# 1032/1032 - 3s - 3ms/step - loss: 0.6375 - val_loss: 0.7563
# Epoch 20/10000
#
# Epoch 20: val_loss did not improve from 0.60503
# 1032/1032 - 2s - 2ms/step - loss: 0.6311 - val_loss: 0.6722
# Epoch 21/10000
#
# Epoch 21: val_loss did not improve from 0.60503
# 1032/1032 - 3s - 2ms/step - loss: 0.6319 - val_loss: 0.7066
# Epoch 22/10000
#
# Epoch 22: val_loss did not improve from 0.60503
# 1032/1032 - 1s - 1ms/step - loss: 0.6152 - val_loss: 0.6965
# Epoch 23/10000
#
# Epoch 23: val_loss improved from 0.60503 to 0.58154, saving model to weights.keras
# 1032/1032 - 1s - 1ms/step - loss: 0.6231 - val_loss: 0.5815
# Epoch 24/10000
#
# Epoch 24: val_loss did not improve from 0.58154
# 1032/1032 - 3s - 3ms/step - loss: 0.6162 - val_loss: 0.6175
# Epoch 25/10000
#
# Epoch 25: val_loss did not improve from 0.58154
# 1032/1032 - 2s - 2ms/step - loss: 0.6140 - val_loss: 0.7361
# Epoch 26/10000
#
# Epoch 26: val_loss did not improve from 0.58154
# 1032/1032 - 1s - 1ms/step - loss: 0.6101 - val_loss: 0.6947
# Epoch 27/10000
#
# Epoch 27: val_loss did not improve from 0.58154
# 1032/1032 - 3s - 2ms/step - loss: 0.6057 - val_loss: 0.6459
# Epoch 28/10000
#
# Epoch 28: val_loss did not improve from 0.58154
# 1032/1032 - 3s - 2ms/step - loss: 0.6075 - val_loss: 0.6084
# Epoch 29/10000
#
# Epoch 29: val_loss did not improve from 0.58154
# 1032/1032 - 1s - 1ms/step - loss: 0.5992 - val_loss: 0.6983
# Epoch 30/10000
#
# Epoch 30: val_loss did not improve from 0.58154
# 1032/1032 - 3s - 3ms/step - loss: 0.5974 - val_loss: 0.6277
# Epoch 31/10000
#
# Epoch 31: val_loss did not improve from 0.58154
# 1032/1032 - 2s - 2ms/step - loss: 0.5939 - val_loss: 0.5989
# Epoch 32/10000
#
# Epoch 32: val_loss improved from 0.58154 to 0.56660, saving model to weights.keras
# 1032/1032 - 3s - 2ms/step - loss: 0.5904 - val_loss: 0.5666
# Epoch 33/10000
#
# Epoch 33: val_loss improved from 0.56660 to 0.54334, saving model to weights.keras
# 1032/1032 - 1s - 1ms/step - loss: 0.5910 - val_loss: 0.5433
# Epoch 34/10000
#
# Epoch 34: val_loss did not improve from 0.54334
# 1032/1032 - 1s - 1ms/step - loss: 0.5825 - val_loss: 0.6621
# Epoch 35/10000
#
# Epoch 35: val_loss did not improve from 0.54334
# 1032/1032 - 3s - 2ms/step - loss: 0.5846 - val_loss: 0.6046
# Epoch 36/10000
#
# Epoch 36: val_loss did not improve from 0.54334
# 1032/1032 - 2s - 2ms/step - loss: 0.5841 - val_loss: 0.6450
# Epoch 37/10000
#
# Epoch 37: val_loss did not improve from 0.54334
# 1032/1032 - 2s - 2ms/step - loss: 0.5859 - val_loss: 0.5925
# Epoch 38/10000
#
# Epoch 38: val_loss did not improve from 0.54334
# 1032/1032 - 1s - 1ms/step - loss: 0.5815 - val_loss: 0.7746
# Epoch 39/10000
#
# Epoch 39: val_loss did not improve from 0.54334
# 1032/1032 - 1s - 1ms/step - loss: 0.5747 - val_loss: 0.6501
# Epoch 40/10000
#
# Epoch 40: val_loss did not improve from 0.54334
# 1032/1032 - 3s - 2ms/step - loss: 0.5744 - val_loss: 0.6366
# Epoch 41/10000
#
# Epoch 41: val_loss did not improve from 0.54334
# 1032/1032 - 2s - 2ms/step - loss: 0.5751 - val_loss: 0.5870
# Epoch 42/10000
#
# Epoch 42: val_loss did not improve from 0.54334
# 1032/1032 - 1s - 1ms/step - loss: 0.5721 - val_loss: 0.5539
# Epoch 43/10000
#
# Epoch 43: val_loss did not improve from 0.54334
# 1032/1032 - 3s - 3ms/step - loss: 0.5663 - val_loss: 0.7889
# Epoch 44/10000
#
# Epoch 44: val_loss did not improve from 0.54334
# 1032/1032 - 2s - 2ms/step - loss: 0.5640 - val_loss: 0.5893
# Epoch 45/10000
#
# Epoch 45: val_loss did not improve from 0.54334
# 1032/1032 - 3s - 2ms/step - loss: 0.5676 - val_loss: 0.6288
# Epoch 46/10000
#
# Epoch 46: val_loss did not improve from 0.54334
# 1032/1032 - 2s - 2ms/step - loss: 0.5530 - val_loss: 0.6022
# Epoch 47/10000
#
# Epoch 47: val_loss did not improve from 0.54334
# 1032/1032 - 1s - 1ms/step - loss: 0.5619 - val_loss: 0.5780
# Epoch 48/10000
#
# Epoch 48: val_loss did not improve from 0.54334
# 1032/1032 - 3s - 2ms/step - loss: 0.5561 - val_loss: 0.6243
# Epoch 49/10000
#
# Epoch 49: val_loss did not improve from 0.54334
# 1032/1032 - 2s - 2ms/step - loss: 0.5636 - val_loss: 0.5563
# Epoch 50/10000
#
# Epoch 50: val_loss did not improve from 0.54334
# 1032/1032 - 2s - 2ms/step - loss: 0.5557 - val_loss: 0.7117
# Epoch 51/10000
#
# Epoch 51: val_loss did not improve from 0.54334
# 1032/1032 - 2s - 2ms/step - loss: 0.5612 - val_loss: 0.5862
# Epoch 52/10000
#
# Epoch 52: val_loss did not improve from 0.54334
# 1032/1032 - 2s - 2ms/step - loss: 0.5535 - val_loss: 0.6126
# Epoch 53/10000
#
# Epoch 53: val_loss did not improve from 0.54334
# 1032/1032 - 1s - 1ms/step - loss: 0.5494 - val_loss: 0.6136
# Epoch 54/10000
#
# Epoch 54: val_loss did not improve from 0.54334
# 1032/1032 - 3s - 2ms/step - loss: 0.5473 - val_loss: 0.5457
# Epoch 55/10000
#
# Epoch 55: val_loss did not improve from 0.54334
# 1032/1032 - 3s - 3ms/step - loss: 0.5425 - val_loss: 0.5605
# Epoch 56/10000
#
# Epoch 56: val_loss did not improve from 0.54334
# 1032/1032 - 2s - 2ms/step - loss: 0.5487 - val_loss: 0.5589
# Epoch 57/10000
#
# Epoch 57: val_loss did not improve from 0.54334
# 1032/1032 - 3s - 2ms/step - loss: 0.5413 - val_loss: 0.5470
# Epoch 58/10000
#
# Epoch 58: val_loss did not improve from 0.54334
# 1032/1032 - 3s - 3ms/step - loss: 0.5466 - val_loss: 0.5788
# Epoch 59/10000
#
# Epoch 59: val_loss did not improve from 0.54334
# 1032/1032 - 1s - 1ms/step - loss: 0.5380 - val_loss: 0.6117
# Epoch 60/10000
#
# Epoch 60: val_loss did not improve from 0.54334
# 1032/1032 - 1s - 1ms/step - loss: 0.5463 - val_loss: 0.5841
# Epoch 61/10000
#
# Epoch 61: val_loss improved from 0.54334 to 0.53288, saving model to weights.keras
# 1032/1032 - 3s - 3ms/step - loss: 0.5326 - val_loss: 0.5329
# Epoch 62/10000
#
# Epoch 62: val_loss did not improve from 0.53288
# 1032/1032 - 1s - 1ms/step - loss: 0.5375 - val_loss: 0.5657
# Epoch 63/10000
#
# Epoch 63: val_loss did not improve from 0.53288
# 1032/1032 - 3s - 2ms/step - loss: 0.5398 - val_loss: 0.5861
# Epoch 64/10000
#
# Epoch 64: val_loss improved from 0.53288 to 0.53078, saving model to weights.keras
# 1032/1032 - 2s - 2ms/step - loss: 0.5364 - val_loss: 0.5308
# Epoch 65/10000
#
# Epoch 65: val_loss did not improve from 0.53078
# 1032/1032 - 1s - 1ms/step - loss: 0.5358 - val_loss: 0.5447
# Epoch 66/10000
#
# Epoch 66: val_loss did not improve from 0.53078
# 1032/1032 - 1s - 1ms/step - loss: 0.5344 - val_loss: 0.5656
# Epoch 67/10000
#
# Epoch 67: val_loss did not improve from 0.53078
# 1032/1032 - 2s - 2ms/step - loss: 0.5317 - val_loss: 0.5815
# Epoch 68/10000
#
# Epoch 68: val_loss did not improve from 0.53078
# 1032/1032 - 2s - 2ms/step - loss: 0.5355 - val_loss: 0.5680
# Epoch 69/10000
#
# Epoch 69: val_loss did not improve from 0.53078
# 1032/1032 - 1s - 1ms/step - loss: 0.5312 - val_loss: 0.5702
# Epoch 70/10000
#
# Epoch 70: val_loss did not improve from 0.53078
# 1032/1032 - 1s - 1ms/step - loss: 0.5300 - val_loss: 0.6255
# Epoch 71/10000
#
# Epoch 71: val_loss did not improve from 0.53078
# 1032/1032 - 1s - 1ms/step - loss: 0.5267 - val_loss: 0.5405
# Epoch 72/10000
#
# Epoch 72: val_loss did not improve from 0.53078
# 1032/1032 - 2s - 2ms/step - loss: 0.5321 - val_loss: 0.6914
# Epoch 73/10000
#
# Epoch 73: val_loss did not improve from 0.53078
# 1032/1032 - 1s - 1ms/step - loss: 0.5242 - val_loss: 0.5914
# Epoch 74/10000
#
# Epoch 74: val_loss did not improve from 0.53078
# 1032/1032 - 2s - 2ms/step - loss: 0.5268 - val_loss: 0.5764
# Epoch 75/10000
#
# Epoch 75: val_loss did not improve from 0.53078
# 1032/1032 - 2s - 2ms/step - loss: 0.5218 - val_loss: 0.6076
# Epoch 76/10000
#
# Epoch 76: val_loss did not improve from 0.53078
# 1032/1032 - 3s - 2ms/step - loss: 0.5156 - val_loss: 0.5467
# Epoch 77/10000
#
# Epoch 77: val_loss did not improve from 0.53078
# 1032/1032 - 1s - 1ms/step - loss: 0.5229 - val_loss: 0.5506
# Epoch 78/10000
#
# Epoch 78: val_loss did not improve from 0.53078
# 1032/1032 - 1s - 1ms/step - loss: 0.5214 - val_loss: 0.5350
# Epoch 79/10000
#
# Epoch 79: val_loss did not improve from 0.53078
# 1032/1032 - 3s - 2ms/step - loss: 0.5181 - val_loss: 0.5413
# Epoch 80/10000
#
# Epoch 80: val_loss improved from 0.53078 to 0.52908, saving model to weights.keras
# 1032/1032 - 2s - 2ms/step - loss: 0.5178 - val_loss: 0.5291
# Epoch 81/10000
#
# Epoch 81: val_loss improved from 0.52908 to 0.52311, saving model to weights.keras
# 1032/1032 - 4s - 3ms/step - loss: 0.5250 - val_loss: 0.5231
# Epoch 82/10000
#
# Epoch 82: val_loss did not improve from 0.52311
# 1032/1032 - 3s - 2ms/step - loss: 0.5174 - val_loss: 0.5895
# Epoch 83/10000
#
# Epoch 83: val_loss did not improve from 0.52311
# 1032/1032 - 1s - 1ms/step - loss: 0.5186 - val_loss: 0.5279
# Epoch 84/10000
#
# Epoch 84: val_loss did not improve from 0.52311
# 1032/1032 - 1s - 1ms/step - loss: 0.5114 - val_loss: 0.5476
# Epoch 85/10000
#
# Epoch 85: val_loss did not improve from 0.52311
# 1032/1032 - 3s - 2ms/step - loss: 0.5171 - val_loss: 0.5523
# Epoch 86/10000
#
# Epoch 86: val_loss did not improve from 0.52311
# 1032/1032 - 2s - 2ms/step - loss: 0.5133 - val_loss: 0.5862
# Epoch 87/10000
#
# Epoch 87: val_loss did not improve from 0.52311
# 1032/1032 - 2s - 2ms/step - loss: 0.5177 - val_loss: 0.5691
# Epoch 88/10000
#
# Epoch 88: val_loss did not improve from 0.52311
# 1032/1032 - 2s - 2ms/step - loss: 0.5142 - val_loss: 0.5822
# Epoch 89/10000
#
# Epoch 89: val_loss did not improve from 0.52311
# 1032/1032 - 2s - 2ms/step - loss: 0.5087 - val_loss: 0.5845
# Epoch 90/10000
#
# Epoch 90: val_loss did not improve from 0.52311
# 1032/1032 - 2s - 2ms/step - loss: 0.5142 - val_loss: 0.5251
# Epoch 91/10000
#
# Epoch 91: val_loss did not improve from 0.52311
# 1032/1032 - 3s - 3ms/step - loss: 0.5140 - val_loss: 0.5531
# Epoch 92/10000
#
# Epoch 92: val_loss did not improve from 0.52311
# 1032/1032 - 2s - 2ms/step - loss: 0.5045 - val_loss: 0.6691
# Epoch 93/10000
#
# Epoch 93: val_loss improved from 0.52311 to 0.52300, saving model to weights.keras
# 1032/1032 - 3s - 3ms/step - loss: 0.5060 - val_loss: 0.5230
# Epoch 94/10000
#
# Epoch 94: val_loss did not improve from 0.52300
# 1032/1032 - 2s - 2ms/step - loss: 0.5114 - val_loss: 0.5436
# Epoch 95/10000
#
# Epoch 95: val_loss did not improve from 0.52300
# 1032/1032 - 3s - 2ms/step - loss: 0.5118 - val_loss: 0.5333
# Epoch 96/10000
#
# Epoch 96: val_loss did not improve from 0.52300
# 1032/1032 - 1s - 1ms/step - loss: 0.5090 - val_loss: 0.5467
# Epoch 97/10000
#
# Epoch 97: val_loss did not improve from 0.52300
# 1032/1032 - 3s - 3ms/step - loss: 0.5056 - val_loss: 0.5692
# Epoch 98/10000
#
# Epoch 98: val_loss did not improve from 0.52300
# 1032/1032 - 2s - 2ms/step - loss: 0.5056 - val_loss: 0.5249
# Epoch 99/10000
#
# Epoch 99: val_loss did not improve from 0.52300
# 1032/1032 - 3s - 2ms/step - loss: 0.5032 - val_loss: 0.5437
# Epoch 100/10000
#
# Epoch 100: val_loss did not improve from 0.52300
# 1032/1032 - 3s - 2ms/step - loss: 0.5038 - val_loss: 0.5477
# Epoch 101/10000
#
# Epoch 101: val_loss did not improve from 0.52300
# 1032/1032 - 2s - 2ms/step - loss: 0.5060 - val_loss: 0.5283
# Epoch 102/10000
#
# Epoch 102: val_loss did not improve from 0.52300
# 1032/1032 - 3s - 3ms/step - loss: 0.5038 - val_loss: 0.5664
# Epoch 103/10000
#
# Epoch 103: val_loss did not improve from 0.52300
# 1032/1032 - 2s - 2ms/step - loss: 0.5005 - val_loss: 0.5683
# Epoch 104/10000
#
# Epoch 104: val_loss did not improve from 0.52300
# 1032/1032 - 1s - 1ms/step - loss: 0.4990 - val_loss: 0.6417
# Epoch 105/10000
#
# Epoch 105: val_loss did not improve from 0.52300
# 1032/1032 - 1s - 1ms/step - loss: 0.5051 - val_loss: 0.5505
# Epoch 106/10000
#
# Epoch 106: val_loss did not improve from 0.52300
# 1032/1032 - 1s - 1ms/step - loss: 0.4988 - val_loss: 0.5400
# Epoch 107/10000
#
# Epoch 107: val_loss did not improve from 0.52300
# 1032/1032 - 1s - 1ms/step - loss: 0.4958 - val_loss: 0.5262
# Epoch 108/10000
#
# Epoch 108: val_loss did not improve from 0.52300
# 1032/1032 - 1s - 1ms/step - loss: 0.4992 - val_loss: 0.5393
# Epoch 109/10000
#
# Epoch 109: val_loss did not improve from 0.52300
# 1032/1032 - 2s - 1ms/step - loss: 0.4950 - val_loss: 0.5737
# Epoch 110/10000
#
# Epoch 110: val_loss did not improve from 0.52300
# 1032/1032 - 3s - 3ms/step - loss: 0.4964 - val_loss: 0.5432
# Epoch 111/10000
#
# Epoch 111: val_loss did not improve from 0.52300
# 1032/1032 - 2s - 2ms/step - loss: 0.4950 - val_loss: 0.5251
# Epoch 112/10000
#
# Epoch 112: val_loss did not improve from 0.52300
# 1032/1032 - 3s - 2ms/step - loss: 0.4956 - val_loss: 0.5973
# Epoch 113/10000
#
# Epoch 113: val_loss did not improve from 0.52300
# 1032/1032 - 1s - 1ms/step - loss: 0.4937 - val_loss: 0.6697
# Epoch 114/10000
#
# Epoch 114: val_loss did not improve from 0.52300
# 1032/1032 - 1s - 1ms/step - loss: 0.4986 - val_loss: 0.5446
# Epoch 115/10000
#
# Epoch 115: val_loss did not improve from 0.52300
# 1032/1032 - 1s - 1ms/step - loss: 0.4893 - val_loss: 0.5395
# Epoch 116/10000
#
# Epoch 116: val_loss did not improve from 0.52300
# 1032/1032 - 2s - 2ms/step - loss: 0.4974 - val_loss: 0.5289
# Epoch 117/10000
#
# Epoch 117: val_loss improved from 0.52300 to 0.52046, saving model to weights.keras
# 1032/1032 - 2s - 2ms/step - loss: 0.4927 - val_loss: 0.5205
# Epoch 118/10000
#
# Epoch 118: val_loss did not improve from 0.52046
# 1032/1032 - 1s - 1ms/step - loss: 0.4905 - val_loss: 0.5407
# Epoch 119/10000
#
# Epoch 119: val_loss did not improve from 0.52046
# 1032/1032 - 1s - 1ms/step - loss: 0.4884 - val_loss: 0.6195
# Epoch 120/10000
#
# Epoch 120: val_loss did not improve from 0.52046
# 1032/1032 - 3s - 3ms/step - loss: 0.4881 - val_loss: 0.5405
# Epoch 121/10000
#
# Epoch 121: val_loss did not improve from 0.52046
# 1032/1032 - 2s - 2ms/step - loss: 0.4881 - val_loss: 0.5856
# Epoch 122/10000
#
# Epoch 122: val_loss did not improve from 0.52046
# 1032/1032 - 2s - 2ms/step - loss: 0.4883 - val_loss: 0.5780
# Epoch 123/10000
#
# Epoch 123: val_loss did not improve from 0.52046
# 1032/1032 - 2s - 2ms/step - loss: 0.4863 - val_loss: 0.5805
# Epoch 124/10000
#
# Epoch 124: val_loss did not improve from 0.52046
# 1032/1032 - 2s - 2ms/step - loss: 0.4851 - val_loss: 0.5297
# Epoch 125/10000
#
# Epoch 125: val_loss did not improve from 0.52046
# 1032/1032 - 1s - 1ms/step - loss: 0.4882 - val_loss: 0.5570
# Epoch 126/10000
#
# Epoch 126: val_loss did not improve from 0.52046
# 1032/1032 - 1s - 1ms/step - loss: 0.4844 - val_loss: 0.5567
# Epoch 127/10000
#
# Epoch 127: val_loss did not improve from 0.52046
# 1032/1032 - 1s - 1ms/step - loss: 0.4898 - val_loss: 0.5857
# Epoch 128/10000
#
# Epoch 128: val_loss did not improve from 0.52046
# 1032/1032 - 3s - 2ms/step - loss: 0.4850 - val_loss: 0.5331
# Epoch 129/10000
#
# Epoch 129: val_loss did not improve from 0.52046
# 1032/1032 - 2s - 2ms/step - loss: 0.4816 - val_loss: 0.5992
# Epoch 130/10000
#
# Epoch 130: val_loss did not improve from 0.52046
# 1032/1032 - 3s - 2ms/step - loss: 0.4807 - val_loss: 0.5237
# Epoch 131/10000
#
# Epoch 131: val_loss did not improve from 0.52046
# 1032/1032 - 1s - 1ms/step - loss: 0.4784 - val_loss: 0.5275
# Epoch 132/10000
#
# Epoch 132: val_loss did not improve from 0.52046
# 1032/1032 - 1s - 1ms/step - loss: 0.4904 - val_loss: 0.5586
# Epoch 133/10000
#
# Epoch 133: val_loss did not improve from 0.52046
# 1032/1032 - 3s - 3ms/step - loss: 0.4795 - val_loss: 0.5238
# Epoch 134/10000
#
# Epoch 134: val_loss did not improve from 0.52046
# 1032/1032 - 2s - 2ms/step - loss: 0.4856 - val_loss: 0.5717
# Epoch 135/10000
#
# Epoch 135: val_loss did not improve from 0.52046
# 1032/1032 - 2s - 2ms/step - loss: 0.4841 - val_loss: 0.5405
# Epoch 136/10000
#
# Epoch 136: val_loss did not improve from 0.52046
# 1032/1032 - 2s - 2ms/step - loss: 0.4850 - val_loss: 0.5430
# Epoch 137/10000
#
# Epoch 137: val_loss did not improve from 0.52046
# 1032/1032 - 2s - 2ms/step - loss: 0.4752 - val_loss: 0.5421
# Epoch 138/10000
#
# Epoch 138: val_loss improved from 0.52046 to 0.51965, saving model to weights.keras
# 1032/1032 - 3s - 2ms/step - loss: 0.4752 - val_loss: 0.5196
# Epoch 139/10000
#
# Epoch 139: val_loss did not improve from 0.51965
# 1032/1032 - 1s - 1ms/step - loss: 0.4800 - val_loss: 0.5497
# Epoch 140/10000
#
# Epoch 140: val_loss did not improve from 0.51965
# 1032/1032 - 3s - 3ms/step - loss: 0.4818 - val_loss: 0.5695
# Epoch 141/10000
#
# Epoch 141: val_loss did not improve from 0.51965
# 1032/1032 - 2s - 2ms/step - loss: 0.4762 - val_loss: 0.5463
# Epoch 142/10000
#
# Epoch 142: val_loss did not improve from 0.51965
# 1032/1032 - 1s - 1ms/step - loss: 0.4782 - val_loss: 0.5235
# Epoch 143/10000
#
# Epoch 143: val_loss did not improve from 0.51965
# 1032/1032 - 1s - 1ms/step - loss: 0.4793 - val_loss: 0.5325
# Epoch 144/10000
#
# Epoch 144: val_loss did not improve from 0.51965
# 1032/1032 - 1s - 1ms/step - loss: 0.4743 - val_loss: 0.5198
# Epoch 145/10000
#
# Epoch 145: val_loss did not improve from 0.51965
# 1032/1032 - 1s - 1ms/step - loss: 0.4752 - val_loss: 0.5571
# Epoch 146/10000
#
# Epoch 146: val_loss did not improve from 0.51965
# 1032/1032 - 1s - 1ms/step - loss: 0.4705 - val_loss: 0.5611
# Epoch 147/10000
#
# Epoch 147: val_loss did not improve from 0.51965
# 1032/1032 - 1s - 1ms/step - loss: 0.4825 - val_loss: 0.5436
# Epoch 148/10000
#
# Epoch 148: val_loss did not improve from 0.51965
# 1032/1032 - 1s - 1ms/step - loss: 0.4729 - val_loss: 0.5242
# Epoch 149/10000
#
# Epoch 149: val_loss improved from 0.51965 to 0.51676, saving model to weights.keras
# 1032/1032 - 3s - 3ms/step - loss: 0.4799 - val_loss: 0.5168
# Epoch 150/10000
#
# Epoch 150: val_loss did not improve from 0.51676
# 1032/1032 - 2s - 2ms/step - loss: 0.4766 - val_loss: 0.5192
# Epoch 151/10000
#
# Epoch 151: val_loss did not improve from 0.51676
# 1032/1032 - 1s - 1ms/step - loss: 0.4712 - val_loss: 0.5232
# Epoch 152/10000
#
# Epoch 152: val_loss did not improve from 0.51676
# 1032/1032 - 1s - 1ms/step - loss: 0.4732 - val_loss: 0.5218
# Epoch 153/10000
#
# Epoch 153: val_loss did not improve from 0.51676
# 1032/1032 - 3s - 2ms/step - loss: 0.4719 - val_loss: 0.5466
# Epoch 154/10000
#
# Epoch 154: val_loss did not improve from 0.51676
# 1032/1032 - 3s - 2ms/step - loss: 0.4727 - val_loss: 0.5278
# Epoch 155/10000
#
# Epoch 155: val_loss did not improve from 0.51676
# 1032/1032 - 2s - 2ms/step - loss: 0.4717 - val_loss: 0.5244
# Epoch 156/10000
#
# Epoch 156: val_loss did not improve from 0.51676
# 1032/1032 - 2s - 2ms/step - loss: 0.4737 - val_loss: 0.5517
# Epoch 157/10000
#
# Epoch 157: val_loss did not improve from 0.51676
# 1032/1032 - 2s - 2ms/step - loss: 0.4684 - val_loss: 0.5200
# Epoch 158/10000
#
# Epoch 158: val_loss did not improve from 0.51676
# 1032/1032 - 1s - 1ms/step - loss: 0.4718 - val_loss: 0.5200
# Epoch 159/10000
#
# Epoch 159: val_loss did not improve from 0.51676
# 1032/1032 - 1s - 1ms/step - loss: 0.4704 - val_loss: 0.5359
# Epoch 160/10000
#
# Epoch 160: val_loss did not improve from 0.51676
# 1032/1032 - 1s - 1ms/step - loss: 0.4698 - val_loss: 0.5797
# Epoch 161/10000
#
# Epoch 161: val_loss did not improve from 0.51676
# 1032/1032 - 3s - 2ms/step - loss: 0.4698 - val_loss: 0.5343
# Epoch 162/10000
#
# Epoch 162: val_loss did not improve from 0.51676
# 1032/1032 - 2s - 2ms/step - loss: 0.4669 - val_loss: 0.5726
# Epoch 163/10000
#
# Epoch 163: val_loss did not improve from 0.51676
# 1032/1032 - 2s - 2ms/step - loss: 0.4633 - val_loss: 0.5496
# Epoch 164/10000
#
# Epoch 164: val_loss did not improve from 0.51676
# 1032/1032 - 1s - 1ms/step - loss: 0.4659 - val_loss: 0.5765
# Epoch 165/10000
#
# Epoch 165: val_loss did not improve from 0.51676
# 1032/1032 - 3s - 2ms/step - loss: 0.4693 - val_loss: 0.5390
# Epoch 166/10000
#
# Epoch 166: val_loss did not improve from 0.51676
# 1032/1032 - 3s - 2ms/step - loss: 0.4668 - val_loss: 0.5173
# Epoch 167/10000
#
# Epoch 167: val_loss did not improve from 0.51676
# 1032/1032 - 2s - 1ms/step - loss: 0.4619 - val_loss: 0.5692
# Epoch 168/10000
#
# Epoch 168: val_loss did not improve from 0.51676
# 1032/1032 - 2s - 2ms/step - loss: 0.4704 - val_loss: 0.5703
# Epoch 169/10000
#
# Epoch 169: val_loss did not improve from 0.51676
# 1032/1032 - 2s - 2ms/step - loss: 0.4676 - val_loss: 0.5239
# Epoch 170/10000
#
# Epoch 170: val_loss did not improve from 0.51676
# 1032/1032 - 3s - 2ms/step - loss: 0.4704 - val_loss: 0.5199
# Epoch 171/10000
#
# Epoch 171: val_loss did not improve from 0.51676
# 1032/1032 - 3s - 2ms/step - loss: 0.4704 - val_loss: 0.5220
# Epoch 172/10000
#
# Epoch 172: val_loss did not improve from 0.51676
# 1032/1032 - 1s - 1ms/step - loss: 0.4705 - val_loss: 0.5289
# Epoch 173/10000
#
# Epoch 173: val_loss did not improve from 0.51676
# 1032/1032 - 3s - 3ms/step - loss: 0.4690 - val_loss: 0.5647
# Epoch 174/10000
#
# Epoch 174: val_loss improved from 0.51676 to 0.51244, saving model to weights.keras
# 1032/1032 - 3s - 3ms/step - loss: 0.4641 - val_loss: 0.5124
# Epoch 175/10000
#
# Epoch 175: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 2ms/step - loss: 0.4674 - val_loss: 0.5216
# Epoch 176/10000
#
# Epoch 176: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 2ms/step - loss: 0.4613 - val_loss: 0.5147
# Epoch 177/10000
#
# Epoch 177: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 2ms/step - loss: 0.4647 - val_loss: 0.5533
# Epoch 178/10000
#
# Epoch 178: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4658 - val_loss: 0.5219
# Epoch 179/10000
#
# Epoch 179: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 3ms/step - loss: 0.4647 - val_loss: 0.5200
# Epoch 180/10000
#
# Epoch 180: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4662 - val_loss: 0.5191
# Epoch 181/10000
#
# Epoch 181: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 2ms/step - loss: 0.4656 - val_loss: 0.5412
# Epoch 182/10000
#
# Epoch 182: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4632 - val_loss: 0.5430
# Epoch 183/10000
#
# Epoch 183: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 2ms/step - loss: 0.4578 - val_loss: 0.5253
# Epoch 184/10000
#
# Epoch 184: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 3ms/step - loss: 0.4634 - val_loss: 0.5634
# Epoch 185/10000
#
# Epoch 185: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 2ms/step - loss: 0.4635 - val_loss: 0.5180
# Epoch 186/10000
#
# Epoch 186: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4604 - val_loss: 0.5197
# Epoch 187/10000
#
# Epoch 187: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4586 - val_loss: 0.5275
# Epoch 188/10000
#
# Epoch 188: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4639 - val_loss: 0.5368
# Epoch 189/10000
#
# Epoch 189: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 2ms/step - loss: 0.4613 - val_loss: 0.5638
# Epoch 190/10000
#
# Epoch 190: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 3ms/step - loss: 0.4607 - val_loss: 0.5272
# Epoch 191/10000
#
# Epoch 191: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 3ms/step - loss: 0.4619 - val_loss: 0.5279
# Epoch 192/10000
#
# Epoch 192: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4713 - val_loss: 0.5269
# Epoch 193/10000
#
# Epoch 193: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4578 - val_loss: 0.5317
# Epoch 194/10000
#
# Epoch 194: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 1ms/step - loss: 0.4644 - val_loss: 0.5578
# Epoch 195/10000
#
# Epoch 195: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4635 - val_loss: 0.5298
# Epoch 196/10000
#
# Epoch 196: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 2ms/step - loss: 0.4617 - val_loss: 0.5157
# Epoch 197/10000
#
# Epoch 197: val_loss did not improve from 0.51244
# 1032/1032 - 4s - 4ms/step - loss: 0.4568 - val_loss: 0.5262
# Epoch 198/10000
#
# Epoch 198: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 3ms/step - loss: 0.4596 - val_loss: 0.5172
# Epoch 199/10000
#
# Epoch 199: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 1ms/step - loss: 0.4605 - val_loss: 0.5282
# Epoch 200/10000
#
# Epoch 200: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 2ms/step - loss: 0.4570 - val_loss: 0.5634
# Epoch 201/10000
#
# Epoch 201: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 2ms/step - loss: 0.4598 - val_loss: 0.5516
# Epoch 202/10000
#
# Epoch 202: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 2ms/step - loss: 0.4621 - val_loss: 0.5328
# Epoch 203/10000
#
# Epoch 203: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 2ms/step - loss: 0.4556 - val_loss: 0.5215
# Epoch 204/10000
#
# Epoch 204: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 2ms/step - loss: 0.4593 - val_loss: 0.5197
# Epoch 205/10000
#
# Epoch 205: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 2ms/step - loss: 0.4556 - val_loss: 0.5185
# Epoch 206/10000
#
# Epoch 206: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4613 - val_loss: 0.5532
# Epoch 207/10000
#
# Epoch 207: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4611 - val_loss: 0.5448
# Epoch 208/10000
#
# Epoch 208: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 2ms/step - loss: 0.4530 - val_loss: 0.5322
# Epoch 209/10000
#
# Epoch 209: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 2ms/step - loss: 0.4550 - val_loss: 0.5314
# Epoch 210/10000
#
# Epoch 210: val_loss did not improve from 0.51244
# 1032/1032 - 2s - 2ms/step - loss: 0.4508 - val_loss: 0.5398
# Epoch 211/10000
#
# Epoch 211: val_loss did not improve from 0.51244
# 1032/1032 - 1s - 1ms/step - loss: 0.4531 - val_loss: 0.5232
# Epoch 212/10000
#
# Epoch 212: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 2ms/step - loss: 0.4554 - val_loss: 0.6310
# Epoch 213/10000
#
# Epoch 213: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 3ms/step - loss: 0.4564 - val_loss: 0.5398
# Epoch 214/10000
#
# Epoch 214: val_loss did not improve from 0.51244
# 1032/1032 - 3s - 3ms/step - loss: 0.4556 - val_loss: 0.5168
# Epoch 214: early stopping

# %% [markdown]
# A tanítás végeztével visszatöltjük a legjobb modellt, és kiértékeljük ennek teljesítményét a teszt adatokon. Mit jelenthet ez az érték?

# %%
model = load_model('weights.keras')

from sklearn.metrics import mean_squared_error
import math

preds = model.predict(X_test)
test_err = mean_squared_error(Y_test,preds)
print("\nTeszt hiba: %f" % (test_err))
print(f"Ez az jelenti, hogy sqrt({test_err:0.3f}))={math.sqrt(test_err):0.3f}-at hibáz átlagosan a modell a teszt adatokon.")
print(f"Ez annyit jelent, hogy átlagosan {math.sqrt(test_err)*100000:0.0f}$-t téved a modellünk.")
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Teszt hiba: 0.306745
# Ez az jelenti, hogy sqrt(0.307))=0.554-at hibáz átlagosan a modell a teszt adatokon.
# Ez annyit jelent, hogy átlagosan 55385$-t téved a modellünk.

# %% [markdown]
# Az eredményeket vizsgáljuk meg grafikusan is:

# %%
import seaborn as sns
sns.set_context("poster")

import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
fig = sns.regplot(x=Y_test, y=preds.reshape(-1));
# fig.set(xlim=(10,30),ylim=(10,30))
plt.xlabel("Ground truth [$ 100 000]")
plt.ylabel("Predictions [$ 100 000]")
plt.show()

# %% [markdown]
# Mit jelent ez az ábra? Mit jelentene egy vízszintes egyenes? És egy függőleges egyenes?
