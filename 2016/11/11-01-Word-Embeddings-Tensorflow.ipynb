# %% [markdown]
# # Copyright
# <PRE>
# Jelen iPython notebook a Budapesti Műszaki és Gazdaságtudományi Egyetemen tartott
# "Deep Learning a gyakorlatban Python és LUA alapon" tantárgy segédanyagaként készült,
# az alábbi forrás alapján:
#  https://github.com/tensorflow/tensorflow/tree/master/tensorflow/examples/tutorials/word2vec
#
# A tantárgy honlapja: http://smartlab.tmit.bme.hu/oktatas-deep-learning
# Deep Learning kutatás: http://smartlab.tmit.bme.hu/deep-learning
#
# A forráskódot GPLv3 licensz védi. Újrafelhasználás esetén lehetőség szerint kérjük az alábbi szerzőt értesíteni.
#
# 2016 (c) Szaszák György (szaszak kukac tmit pont bme pont hu)
# </PRE>

# %% [markdown]
# ## Szövegkorpusz és tokenizálása
# A wikipédia mentését tartalmazó nagy szövegkorpuszt használunk. Tömrítve tárolt, kicsomagolás után tokenizáljuk: azaz szavakra bontjuk, az írásjeleket kidobáljuk belőle. Ehhez először töltsük le az adatbázist, amivel dolgozni fogunk (console-ból futtasuk az alábbi parancsot):

# %% [markdown]
#     wget http://mattmahoney.net/dc/text8.zip -O text8.zip

# %% [markdown]
# Majd töltsük be ezt:

# %%
# -*- coding: utf-8 -*-

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import xrange
import tensorflow as tf

# Angol wikipédiáról származó adatok
filename="text8.zip"

# Kicsomagoljuk és beolvassuk a fájlt, listába kerülnek belőle a szavak egymás után, ahogy jönnek (.split())
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Szavak száma: ', len(words))
# Out:
# Szavak száma:  17005207

# %% [markdown]
# ## Összerakjuk a szótárat és a tanítómintákat listába tesszük
# Mivel nagyon sok különböző szó van, húzunk egy plafont, mennyi különböző szót modellezünk. A többit kihagyjuk és egy közös "ismeretlen" szimbólumra változtatjuk. Természetesen az a célszerű, ha gyakoriság szerint rendezzük a szótárat és a leggyakoribbakat megtartjuk, és a ritkákból hagyunk veszni. A ritkaság miatt úgyis nehéz lenne a modellezés.
# Ha ezzel megvagyunk, egész azonosíót rendelünk sorban a szavakhoz. Ezt egy szótárba tesszük, és az inverz átalakítást is elkészítjük hozzá, hogy számokat vissza tudjunk alakítani szavakra.

# %%
vocabulary_size = 50000 # Maximum szavak száma (ami nem fér bele, egy közös "szemeteskosárra" képezzük: UNK

def build_dataset(words):
  count = [['UNK', -1]] # Countban a szavak és hogy hány van belőlük. Az UNK is egy szó, amelyre az összes ismeretlent képezzük le, értékét később állítjuk be.
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1)) # Gyakorisági sorrendbe rendezzük, mert csak a leggyakoribb szavakat tartjuk meg
  dictionary = dict() # Ez lesz a szó -> egész azonosító leképezés tábla
  for word, _ in count: # Végigmegyünk az összes szón...
    dictionary[word] = len(dictionary) # Bekerül a szótárba
  data = list() # data fogja tartalmazni a szavak számokra leképzett alakját listaként
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK'] a 0. elem
      unk_count += 1 # Számoljuk, hány olyan szó van, amelyet UNK-ra képztünk le (mert ritka)
    data.append(index)
  count[0][1] = unk_count # UNK 0. elem a countban, annak második tagja az előfordulások száma
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  # Visszaadjuk az adatokat (lista, szavak egész azonsítóval benne); a szavak és előfordulásaik számának tömbjét (count),
  # a szótárat (szavak -> szám) és a fordítottját (szám -> szó)
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Memóriatakarékosság végett
print('Az 5 leggyakoribb szó (+UNK)', count[:5])
print('Az adatokból az első 16 minta', data[:16], [reverse_dictionary[i] for i in data[:16]])

data_index = 0
# Out:
# Az 5 leggyakoribb szó (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Az adatokból az első 16 minta [5243, 3084, 12, 6, 195, 2, 3134, 46, 59, 156, 128, 742, 477, 10616, 134, 1] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']

# %% [markdown]
# ## Minibatch genenerátort csinálunk skip gram tanításához
# A skip gram egy adott szóra (target) ad  kontextusbecslést. Tanításakor a skip_window által megadott intervallumban egy adott target szó körül vizsgálódunk. Innen num_skips mintát veszünk véletlenszerűen a kontextusból.

# %%
def generate_batch(batch_size, num_skips, skip_window):
  global data_index # A globális változó azért kell, hogy ismételt híváskor ne induljunk megint elölről
  assert batch_size % num_skips == 0 # egész számnak kell lennie, ennyi szó megy a bemenetre majd
  assert num_skips <= 2 * skip_window # nem lóghatunk ki az ablakból akkor sem, ha a teljes kontextust használjuk
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # A minta két oldalára tesszük rá a skip_window-t: [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span) # deque: kétoldalt bővíthető lista
  for _ in range(span):
    buffer.append(data[data_index]) # buffer-be betesszük az érintett szavakat; közepén a bemenet, tőle balra-jobbra kimenetek
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips): # ennyi szóra tudunk most mintát generálni
    target = skip_window  # bemenet (target, mert a skip gramban az input és target helyet cserélnek) a buffer középső eleme tehát
    targets_to_avoid = [ skip_window ] # aki már volt, többet ne legyen
    for j in range(num_skips): # ennyi mintát veszünk a kimenetre adott bemenethez
      while target in targets_to_avoid:
        target = random.randint(0, span - 1) # Véletlenszerű mintavételezés a szó előtt és után skip_windowon belüli elemekből
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window] # Bemenet, num_skip-szer ismétlődik
      labels[i * num_skips + j, 0] = buffer[target] # az egyes kiemenetek (num_skip darab egy bemenetre)
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %% [markdown]
# ## Példaként generálunk egy rövid batch-et
# Meg lehet figyelni, hogy data_indexhez képesti skip_window-adik szótól indul, kimenetre ad mellé num_skip elemet.

# %%
print('Az adatokból az első 16 minta', data[:16], [reverse_dictionary[i] for i in data[:16]])
data_index=0
print ("Data index: ", data_index)
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

#for i in range(8):
 # print(batch[i], reverse_dictionary[batch[i]],
  #    '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

print ("="*50)
print ("Data index: ", data_index)
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=2)


for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

print ("Data index: ", data_index)
# Out:
# Az adatokból az első 16 minta [5243, 3084, 12, 6, 195, 2, 3134, 46, 59, 156, 128, 742, 477, 10616, 134, 1] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
# Data index:  0
# ==================================================
# Data index:  7
# 156 against -> 59 used
# 156 against -> 742 working
# 128 early -> 59 used
# 128 early -> 742 working
# 742 working -> 477 class
# 742 working -> 128 early
# 477 class -> 134 including
# 477 class -> 128 early
# Data index:  16

# %% [markdown]
# ## Modell összeállítása
# Most már rendes batch-eket csinálunk, végig a korpuszon. Közben készül egy pici validációs halmaz is, hogy tanulás közben tudjunk logolni.

# %%
batch_size = 128
embedding_size = 128  # embedding dimenziós (órán N volt)
skip_window = 1       # Balról is és jobbról is ennyi mintát veszünk a szó környezetéből
num_skips = 2         # Hányszor használjunk egy bemenetet (pl. skip_window * 2, de ha kevesebb, akkor mintavételezünk egy tágabb szókontextust

# Csinálunk egy random validációs halmazt
valid_size = 16	    # Minták száma validációhoz
valid_window = 100  # Csak a 100 leggyakoribb szóból
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # A negatív minták száma lesz majd ennyi

graph = tf.Graph()

with graph.as_default():

  # Input adatok
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # CPU / GPU
  with tf.device('/cpu:0'):  # with tf.device('/gpu:0'):
    # Embeddingek, V x N, random init, bemenetre kötve
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # NCE (Noise Contrastive Estimation) loss-t fogunk számolni, ehhez segédváltozók
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # A tf.nce_loss minden kiértékelésre új negatív mintákat (szavakat) generál
  loss = tf.reduce_mean(
      tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                     num_sampled, vocabulary_size))

  # SGD, tanulási ráta: 1.0 (nagy!).
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Koszinusz hasonlóság a minibatchban kapott és a meglévő embeddingek között
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

    # Inicializáljuk a változókat
  init = tf.initialize_all_variables()

# %% [markdown]
# ## Tanítjuk a modellt
# Közben logoljuk a választott validációs halmazra a 8, a target kontextusaként leggyakrabban előforduló szót.

# %%
# Tanítás
num_steps = 100001

with tf.Session(graph=graph) as session:
    
  init.run() # Inicializálás

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # Update és loss számítása a validációs halmazon (random minták a 100 leggyakoribb szóból)
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # 2000 batchenként átlagos hibát számolunk
      print("Átlagos hiba a ", step, ". lépésben : ", average_loss)
      average_loss = 0

    # Hasonlóság logolása 10000 batchenként (nem gyakrabban, mert számításigényes nagyon)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 6 # k legközelebbi szomszéd
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = " %s -> " % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Átlagos hiba a  0 . lépésben :  286.555206299
#  they ->  headstock, displeased, nearby, stayed, transformed, clinched,
#  some ->  visualized, newsstand, angiosperm, tuberculosis, hawaiian, anglican,
#  all ->  branding, criminalized, laminar, prototypical, kickboxing, toland,
#  six ->  provisional, telomeres, writs, differentiate, shimazu, iconography,
#  use ->  upgrades, protestant, ad, krypton, spink, scotland,
#  these ->  raymond, anglican, inflict, utilitarian, believes, derision,
#  history ->  peacefully, nico, aleksandar, furthering, jailed, adamant,
#  many ->  sterling, hershey, procedures, sideband, microsite, fruits,
#  new ->  outfits, macrostate, jonah, visited, keeling, hypertext,
#  as ->  thru, neurological, bismuth, bnls, insects, primarily,
#  a ->  initiates, traffic, vocalizations, dakuten, harmonious, teotihuacan,
#  with ->  canadians, dte, inviscid, founds, bankrupt, sextet,
#  not ->  promised, mediawiki, cordilleras, marche, bonfires, nations,
#  after ->  treachery, tehran, possibility, karate, papuan, yolande,
#  is ->  rcs, frasier, challenger, biochemical, tiffany, interpolating,
#  s ->  materia, willful, antics, clays, narrative, kinetochore,
# Átlagos hiba a  2000 . lépésben :  113.824750415
# Átlagos hiba a  4000 . lépésben :  53.443482265
# Átlagos hiba a  6000 . lépésben :  33.155487577
# Átlagos hiba a  8000 . lépésben :  22.7741551827
# Átlagos hiba a  10000 . lépésben :  17.9549903527
#  they ->  rogers, active, bulb, there, transformed, probably,
#  some ->  rainforest, hawaiian, tuberculosis, anglican, dasyprocta, a,
#  all ->  demanded, gel, crucial, wolf, dasyprocta, lyric,
#  six ->  nine, four, seven, zero, eight, agouti,
#  use ->  dasyprocta, protestant, scotland, solution, cause, aquila,
#  these ->  raymond, anglican, carroll, never, saying, believes,
#  history ->  killing, aleksandar, antwerp, aquatic, trebizond, saxon,
#  many ->  sterling, alpacas, hear, fruits, procedures, oriented,
#  new ->  involved, visited, leap, operatorname, acacias, upset,
#  as ->  dasyprocta, and, in, anglo, was, is,
#  a ->  the, archives, dasyprocta, it, antwerp, one,
#  with ->  in, dasyprocta, by, and, of, architecture,
#  not ->  permit, promised, opportunity, to, annihilation, carrier,
#  after ->  treachery, possibility, agouti, dasyprocta, witty, juice,
#  is ->  was, in, operatorname, are, has, dasyprocta,
#  s ->  and, which, the, or, nouns, UNK,
# Átlagos hiba a  12000 . lépésben :  13.6758011431
# Átlagos hiba a  14000 . lépésben :  11.4945654248
# Átlagos hiba a  16000 . lépésben :  10.0716675967
# Átlagos hiba a  18000 . lépésben :  8.76128229177
# Átlagos hiba a  20000 . lépésben :  8.07220787859
#  they ->  there, he, bulb, semiconductor, stryker, rogers,
#  some ->  rainforest, the, abet, hawaiian, tuberculosis, iodine,
#  all ->  prototypical, abet, wolf, demanded, crucial, deduced,
#  six ->  nine, eight, four, seven, zero, five,
#  use ->  dasyprocta, upgrades, protestant, solution, scotland, callisto,
#  these ->  raymond, anglican, inflict, saying, almighty, believes,
#  history ->  killing, antwerp, aleksandar, visigoths, aquatic, saxon,
#  many ->  spp, sterling, tretyakov, the, some, hear,
#  new ->  visited, involved, leap, operatorname, acacias, upset,
#  as ->  and, by, dasyprocta, is, with, was,
#  a ->  the, schema, abet, archives, abitibi, recorder,
#  with ->  and, in, by, for, of, from,
#  not ->  to, we, permit, disrupted, that, it,
#  after ->  amalthea, and, in, treachery, seven, camilla,
#  is ->  was, are, has, as, in, and,
#  s ->  and, the, or, of, zero, eight,
# Átlagos hiba a  22000 . lépésben :  7.3188672092
# Átlagos hiba a  24000 . lépésben :  7.06028247428
# Átlagos hiba a  26000 . lépésben :  6.83137693262
# Átlagos hiba a  28000 . lépésben :  5.88663657379
# Átlagos hiba a  30000 . lépésben :  6.17485853612
#  they ->  there, he, it, we, not, lycus,
#  some ->  many, rainforest, the, hawaiian, these, abet,
#  all ->  prototypical, abet, wolf, any, demanded, deduced,
#  six ->  four, seven, eight, three, five, nine,
#  use ->  dasyprocta, upgrades, solution, callisto, protestant, cause,
#  these ->  some, raymond, almighty, anglican, interact, believes,
#  history ->  killing, visigoths, amok, antwerp, aleksandar, aquatic,
#  many ->  some, spp, sterling, tretyakov, every, several,
#  new ->  visited, operatorname, leap, involved, acacias, upset,
#  as ->  by, is, dasyprocta, and, with, in,
#  a ->  the, schema, recorder, archives, this, abet,
#  with ->  in, and, by, for, kohl, as,
#  not ->  to, it, we, that, they, permit,
#  after ->  amalthea, in, four, seven, during, and,
#  is ->  was, are, has, were, as, kohl,
#  s ->  and, or, zero, the, two, his,
# Átlagos hiba a  32000 . lépésben :  5.78526805973
# Átlagos hiba a  34000 . lépésben :  5.70721900785
# Átlagos hiba a  36000 . lépésben :  5.57187924516
# Átlagos hiba a  38000 . lépésben :  5.39694182515
# Átlagos hiba a  40000 . lépésben :  5.33355192971
#  they ->  he, there, we, it, who, not,
#  some ->  many, these, iodine, abet, rainforest, hawaiian,
#  all ->  abet, prototypical, thibetanus, kapoor, buckner, wolf,
#  six ->  four, eight, five, seven, three, two,
#  use ->  dasyprocta, solution, callisto, cause, upgrades, scotland,
#  these ->  some, raymond, almighty, interact, dealer, secured,
#  history ->  killing, amok, visigoths, aleksandar, operatorname, antwerp,
#  many ->  some, several, spp, tretyakov, sterling, jed,
#  new ->  visited, leap, operatorname, outfits, acacias, involved,
#  as ->  by, dasyprocta, is, abet, kapoor, thibetanus,
#  a ->  the, schema, abet, abitibi, archives, musa,
#  with ->  in, and, by, from, kohl, for,
#  not ->  to, we, it, they, also, disrupted,
#  after ->  amalthea, arctos, during, in, when, four,
#  is ->  was, are, has, as, thibetanus, roshan,
#  s ->  zero, and, of, his, ursus, indifferent,
# Átlagos hiba a  42000 . lépésben :  5.47621293962
# Átlagos hiba a  44000 . lépésben :  5.33261099124
# Átlagos hiba a  46000 . lépésben :  5.32553863931
# Átlagos hiba a  48000 . lépésben :  5.19927141297
# Átlagos hiba a  50000 . lépésben :  5.29182492781
#  they ->  he, there, we, it, who, not,
#  some ->  many, these, marmoset, abet, iodine, microsite,
#  all ->  three, microcebus, abet, thibetanus, any, prototypical,
#  six ->  eight, five, four, seven, three, nine,
#  use ->  dasyprocta, solution, callithrix, michelob, cause, upgrades,
#  these ->  some, many, almighty, raymond, interact, secured,
#  history ->  callithrix, killing, amok, visigoths, operatorname, marmoset,
#  many ->  some, several, microsite, these, spp, tamarin,
#  new ->  outfits, cebus, visited, leap, acacias, operatorname,
#  as ->  by, dasyprocta, and, callithrix, microsite, wct,
#  a ->  the, schema, callithrix, microcebus, archives, abet,
#  with ->  and, in, by, callithrix, for, between,
#  not ->  they, to, we, it, disrupted, also,
#  after ->  during, in, when, amalthea, before, arctos,
#  is ->  was, are, has, roshan, thibetanus, became,
#  s ->  zero, his, and, ursus, indifferent, thinkpad,
# Átlagos hiba a  52000 . lépésben :  4.97125431186
# Átlagos hiba a  54000 . lépésben :  4.83777816856
# Átlagos hiba a  56000 . lépésben :  5.18927969921
# Átlagos hiba a  58000 . lépésben :  5.05122055602
# Átlagos hiba a  60000 . lépésben :  4.8990314014
#  they ->  there, he, we, it, who, you,
#  some ->  many, these, the, marmoset, iodine, abet,
#  all ->  microcebus, any, many, michelob, kapoor, abet,
#  six ->  eight, four, seven, five, three, nine,
#  use ->  dasyprocta, solution, callithrix, cause, michelob, upgrades,
#  these ->  some, many, pittsburg, their, such, almighty,
#  history ->  callithrix, amok, killing, operatorname, marmoset, visigoths,
#  many ->  some, several, these, microsite, spp, tamarin,
#  new ->  outfits, visited, cebus, acacias, leap, operatorname,
#  as ->  by, dasyprocta, callithrix, thibetanus, wct, is,
#  a ->  the, schema, callithrix, microcebus, targum, thaler,
#  with ->  in, between, by, when, callithrix, affirmation,
#  not ->  they, we, to, it, still, azathoth,
#  after ->  during, when, before, in, amalthea, arctos,
#  is ->  was, are, has, thibetanus, roshan, became,
#  s ->  thinkpad, zero, his, indifferent, governorates, ursus,
# Átlagos hiba a  62000 . lépésben :  4.93631295109
# Átlagos hiba a  64000 . lépésben :  4.91206141531
# Átlagos hiba a  66000 . lépésben :  4.97339687401
# Átlagos hiba a  68000 . lépésben :  4.86946024948
# Átlagos hiba a  70000 . lépésben :  4.89411331749
#  they ->  he, we, there, you, it, who,
#  some ->  many, these, marmoset, abet, other, callithrix,
#  all ->  many, any, kapoor, microcebus, some, michelob,
#  six ->  seven, five, four, eight, three, nine,
#  use ->  dasyprocta, solution, cause, callithrix, michelob, ordinance,
#  these ->  some, many, pittsburg, such, their, which,
#  history ->  killing, callithrix, amok, operatorname, visigoths, marmoset,
#  many ->  some, several, these, microsite, other, all,
#  new ->  outfits, visited, cebus, leap, acacias, ecc,
#  as ->  by, dasyprocta, microsite, fachhochschule, kapoor, callithrix,
#  a ->  the, schema, callithrix, microcebus, musa, thaler,
#  with ->  between, in, by, for, when, or,
#  not ->  they, to, we, it, still, disrupted,
#  after ->  during, when, before, fachhochschule, amalthea, through,
#  is ->  was, has, are, thibetanus, roshan, became,
#  s ->  thinkpad, zero, his, ursus, indifferent, rfc,
# Átlagos hiba a  72000 . lépésben :  4.918035676
# Átlagos hiba a  74000 . lépésben :  4.88787314773
# Átlagos hiba a  76000 . lépésben :  4.87380813086
# Átlagos hiba a  78000 . lépésben :  4.76086692095
# Átlagos hiba a  80000 . lépésben :  4.78489461732
#  they ->  he, we, there, you, it, not,
#  some ->  many, these, several, all, other, the,
#  all ->  many, some, any, microcebus, michelob, prototypical,
#  six ->  seven, five, eight, four, three, nine,
#  use ->  dasyprocta, solution, callithrix, cause, michelob, agouti,
#  these ->  some, many, such, pittsburg, which, two,
#  history ->  callithrix, killing, amok, operatorname, marmoset, visigoths,
#  many ->  some, several, these, microsite, all, other,
#  new ->  outfits, cebus, visited, ecc, acacias, leap,
#  as ->  dasyprocta, and, fachhochschule, by, microsite, klister,
#  a ->  the, schema, callithrix, another, thaler, microcebus,
#  with ->  between, in, callithrix, dasyprocta, when, by,
#  not ->  they, we, still, it, to, disrupted,
#  after ->  during, when, before, in, fachhochschule, through,
#  is ->  was, has, are, thibetanus, roshan, callithrix,
#  s ->  indifferent, thinkpad, his, ursus, marmoset, and,
# Átlagos hiba a  82000 . lépésben :  4.78822199535
# Átlagos hiba a  84000 . lépésben :  4.68102333522
# Átlagos hiba a  86000 . lépésben :  4.78097000289
# Átlagos hiba a  88000 . lépésben :  4.68624808902
# Átlagos hiba a  90000 . lépésben :  4.73026603937
#  they ->  there, we, he, you, it, not,
#  some ->  many, these, several, all, other, this,
#  all ->  many, some, any, these, microcebus, michelob,
#  six ->  seven, four, five, eight, three, nine,
#  use ->  dasyprocta, callithrix, solution, cause, michelob, aquila,
#  these ->  some, many, such, pittsburg, all, their,
#  history ->  killing, callithrix, amok, visigoths, marmoset, amount,
#  many ->  some, several, these, all, microsite, tamarin,
#  new ->  outfits, cebus, leap, acacias, ecc, visited,
#  as ->  dasyprocta, fachhochschule, klister, microsite, microcebus, callithrix,
#  a ->  the, schema, callithrix, musa, microcebus, any,
#  with ->  between, in, when, callithrix, dasyprocta, kohl,
#  not ->  they, still, usually, to, it, we,
#  after ->  before, during, when, fachhochschule, through, eurocents,
#  is ->  was, has, are, thibetanus, roshan, became,
#  s ->  his, ursus, thinkpad, marmoset, indifferent, the,
# Átlagos hiba a  92000 . lépésben :  4.75561835229
# Átlagos hiba a  94000 . lépésben :  4.69369288135
# Átlagos hiba a  96000 . lépésben :  4.6759797709
# Átlagos hiba a  98000 . lépésben :  4.67604294395
# Átlagos hiba a  100000 . lépésben :  4.5988892175
#  they ->  we, there, he, you, it, who,
#  some ->  many, these, several, all, other, this,
#  all ->  many, some, these, any, michelob, microcebus,
#  six ->  seven, five, four, eight, three, nine,
#  use ->  dasyprocta, cause, solution, callithrix, catahoula, michelob,
#  these ->  some, many, such, all, pittsburg, their,
#  history ->  callithrix, killing, amok, marmoset, operatorname, ssbn,
#  many ->  some, several, these, all, microsite, most,
#  new ->  outfits, cebus, leap, ecc, acacias, callithrix,
#  as ->  fachhochschule, dasyprocta, klister, when, microcebus, microsite,
#  a ->  schema, the, callithrix, microcebus, any, catolica,
#  with ->  between, in, by, when, callithrix, affirmation,
#  not ->  they, still, usually, it, often, also,
#  after ->  when, before, during, fachhochschule, in, through,
#  is ->  was, has, are, roshan, thibetanus, became,
#  s ->  his, thinkpad, marmoset, ursus, indifferent, microcebus,

# %% [markdown]
# ## Embeddingek megjelenítése 2D ábrán

# %%
def plot_with_labels(low_dim_embs, labels):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.show()

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
