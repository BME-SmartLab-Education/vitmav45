# %% [markdown]
# # Copyright
# <pre>
# Jelen forráskód a Budapesti Műszaki és Gazdaságtudományi Egyetemen
# tartott "Deep Learning a gyakorlatban Python és LUA alapon" tantárgy segédanyagaként készült.
#
# A tantárgy honlapja: http://smartlab.tmit.bme.hu/oktatas-deep-learning
# Deep Learning kutatás: http://smartlab.tmit.bme.hu/deep-learning
#
# A forráskódot GPLv3 licensz védi. Újrafelhasználás esetén lehetőség szerint kérejük az alábbi szerzőt értesíteni.
#
# 2023 (c) Gyires-Tóth Bálint (toth.b kukac tmit pont bme pont hu), Zainkó Csaba
# </pre>

# %% [markdown]
# Jelen notebook egy példakódot mutat be egy dimenziós konvolúció alapú szekvenciális adat modellezésre. A példakód elsődlegesen az 1D konvolúcióra koncentrál, az általános megfontolások (standardizálás, min-max skálázás, early stopping, regularizáció, stb.) itt nem szerepelnek, de éles feladatokban szükségszerűek.

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, Flatten, Conv1D, MaxPooling1D
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt

# %% [markdown]
# Az egy dimenziós konvolúciós rétegek létrehozása.

# %%
def make_1d_convnet(window_size, filter_length, nb_input_series=1, nb_outputs=1, nb_filter=4):
    model = Sequential()
    model.add(Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu', input_shape=(window_size, nb_input_series)))
    model.add(MaxPooling1D())
    model.add(Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu'))
    model.add(MaxPooling1D())
    model.add(Flatten())
    model.add(Dense(nb_outputs, activation='linear'))
    model.compile(loss='mse', optimizer='adam', metrics=['mae'])
    return model

# %% [markdown]
# Az idősor adatokból az egy dimenziós konvolúció számára megfelelő formátum létrehozása.

# %%
def make_timeseries_instances(timeseries, window_size):
    timeseries = np.asarray(timeseries)
    assert 0 < window_size < timeseries.shape[0] , "Out of range 0 < {} < {} ".format(window_size,timeseries.shape[0])
    X = np.atleast_3d(np.array([timeseries[start:start + window_size] for start in range(0, timeseries.shape[0] - window_size)]))
    Y = timeseries[window_size:]
    return X, Y

# %% [markdown]
# A hálózat létrehozását, adatok formázását és tanítását az alábbi függvény végzi, és visszatér a predikcióval és az eredeti értékekkel:

# %%
def evaluate_timeseries(timeseries, window_size, valid_split=0.15, test_split=0.15):
    filter_length = 5
    nb_filter = 4
    timeseries = np.atleast_2d(timeseries)
    if timeseries.shape[0] == 1:
        timeseries = timeseries.T       # 1D vektor -> 2D matrix
    nb_samples, nb_series = timeseries.shape
    model = make_1d_convnet(window_size=window_size, filter_length=filter_length, nb_input_series=nb_series, nb_outputs=nb_series, nb_filter=nb_filter)
    model.summary()
    X, Y = make_timeseries_instances(timeseries, window_size)

    valid_size = int(nb_samples*(1-test_split-valid_split))
    test_size = int(nb_samples*(1-test_split))
    X_train, Y_train = X[:valid_size], Y[:valid_size]
    X_valid, Y_valid = X[valid_size:test_size], Y[valid_size:test_size]
    X_test, Y_test   = X[test_size:], Y[test_size:]

    model.fit(X_train, Y_train, epochs=50, batch_size=16, validation_data=(X_valid, Y_valid), verbose=2)

    preds   = model.predict(X_test)

    return Y_test, preds

# %% [markdown]
# Minta adatok létrehozása és megjelenítése:

# %%
# adatok elkészítése
lp 	= np.linspace(-10*np.pi,10*np.pi,1000)
X 	= np.sin(lp)*3+np.cos(lp*2)+np.sin(np.pi/2+lp*4)*1.5+np.log(np.abs(lp))

# %%
plt.figure(figsize=(12,8))
plt.plot(X)

# %% [markdown]
# Tanítás elindítása:

# %%
window_size = 20
targets, preds = evaluate_timeseries(X, window_size)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 16, 4)               │              24 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 8, 4)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 4, 4)                │              84 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 2, 4)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 117 (468.00 B)
#  Trainable params: 117 (468.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 44/44 - 8s - 177ms/step - loss: 10.4199 - mae: 2.7753 - val_loss: 11.2319 - val_mae: 2.8991
# Epoch 2/50
# 44/44 - 0s - 5ms/step - loss: 7.3574 - mae: 2.3453 - val_loss: 6.5949 - val_mae: 2.2312
# Epoch 3/50
# 44/44 - 0s - 6ms/step - loss: 5.1483 - mae: 1.8757 - val_loss: 5.1338 - val_mae: 1.8359
# Epoch 4/50
# 44/44 - 0s - 5ms/step - loss: 4.5857 - mae: 1.7249 - val_loss: 4.8656 - val_mae: 1.7794
# Epoch 5/50
# 44/44 - 0s - 5ms/step - loss: 4.1639 - mae: 1.6334 - val_loss: 4.5364 - val_mae: 1.7178
# Epoch 6/50
# 44/44 - 0s - 6ms/step - loss: 3.6876 - mae: 1.5268 - val_loss: 4.0591 - val_mae: 1.6213
# Epoch 7/50
# 44/44 - 0s - 6ms/step - loss: 3.2427 - mae: 1.4344 - val_loss: 3.5507 - val_mae: 1.5274
# Epoch 8/50
# 44/44 - 0s - 6ms/step - loss: 2.8029 - mae: 1.3265 - val_loss: 3.0889 - val_mae: 1.4330
# Epoch 9/50
# 44/44 - 0s - 7ms/step - loss: 2.4155 - mae: 1.2403 - val_loss: 2.6024 - val_mae: 1.3145
# Epoch 10/50
# 44/44 - 1s - 13ms/step - loss: 2.0353 - mae: 1.1369 - val_loss: 2.1070 - val_mae: 1.1650
# Epoch 11/50
# 44/44 - 0s - 5ms/step - loss: 1.7026 - mae: 1.0441 - val_loss: 1.7030 - val_mae: 1.0480
# Epoch 12/50
# 44/44 - 0s - 7ms/step - loss: 1.3883 - mae: 0.9395 - val_loss: 1.3941 - val_mae: 0.9446
# Epoch 13/50
# 44/44 - 0s - 7ms/step - loss: 1.1770 - mae: 0.8683 - val_loss: 1.1106 - val_mae: 0.8344
# Epoch 14/50
# 44/44 - 0s - 5ms/step - loss: 0.9976 - mae: 0.7959 - val_loss: 0.9303 - val_mae: 0.7798
# Epoch 15/50
# 44/44 - 0s - 5ms/step - loss: 0.8765 - mae: 0.7525 - val_loss: 0.8016 - val_mae: 0.7299
# Epoch 16/50
# 44/44 - 0s - 7ms/step - loss: 0.7969 - mae: 0.7292 - val_loss: 0.7031 - val_mae: 0.6713
# Epoch 17/50
# 44/44 - 0s - 5ms/step - loss: 0.7275 - mae: 0.6885 - val_loss: 0.6388 - val_mae: 0.6570
# Epoch 18/50
# 44/44 - 0s - 7ms/step - loss: 0.6836 - mae: 0.6706 - val_loss: 0.5916 - val_mae: 0.6213
# Epoch 19/50
# 44/44 - 0s - 5ms/step - loss: 0.6534 - mae: 0.6533 - val_loss: 0.5539 - val_mae: 0.6269
# Epoch 20/50
# 44/44 - 0s - 4ms/step - loss: 0.6280 - mae: 0.6431 - val_loss: 0.5199 - val_mae: 0.5992
# Epoch 21/50
# 44/44 - 0s - 10ms/step - loss: 0.6064 - mae: 0.6341 - val_loss: 0.4964 - val_mae: 0.5965
# Epoch 22/50
# 44/44 - 1s - 12ms/step - loss: 0.5881 - mae: 0.6227 - val_loss: 0.4821 - val_mae: 0.5739
# Epoch 23/50
# 44/44 - 0s - 5ms/step - loss: 0.5717 - mae: 0.6133 - val_loss: 0.4561 - val_mae: 0.5684
# Epoch 24/50
# 44/44 - 0s - 5ms/step - loss: 0.5451 - mae: 0.5988 - val_loss: 0.4416 - val_mae: 0.5540
# Epoch 25/50
# 44/44 - 0s - 4ms/step - loss: 0.5394 - mae: 0.5911 - val_loss: 0.4417 - val_mae: 0.5679
# Epoch 26/50
# 44/44 - 0s - 5ms/step - loss: 0.5220 - mae: 0.5818 - val_loss: 0.4095 - val_mae: 0.5420
# Epoch 27/50
# 44/44 - 0s - 4ms/step - loss: 0.5066 - mae: 0.5771 - val_loss: 0.3993 - val_mae: 0.5318
# Epoch 28/50
# 44/44 - 0s - 4ms/step - loss: 0.4900 - mae: 0.5619 - val_loss: 0.3823 - val_mae: 0.5212
# Epoch 29/50
# 44/44 - 0s - 4ms/step - loss: 0.4744 - mae: 0.5538 - val_loss: 0.3740 - val_mae: 0.5091
# Epoch 30/50
# 44/44 - 0s - 8ms/step - loss: 0.4640 - mae: 0.5518 - val_loss: 0.3607 - val_mae: 0.5002
# Epoch 31/50
# 44/44 - 0s - 6ms/step - loss: 0.4522 - mae: 0.5427 - val_loss: 0.3476 - val_mae: 0.4970
# Epoch 32/50
# 44/44 - 0s - 4ms/step - loss: 0.4442 - mae: 0.5394 - val_loss: 0.3468 - val_mae: 0.4863
# Epoch 33/50
# 44/44 - 0s - 7ms/step - loss: 0.4319 - mae: 0.5261 - val_loss: 0.3359 - val_mae: 0.4785
# Epoch 34/50
# 44/44 - 0s - 4ms/step - loss: 0.4214 - mae: 0.5208 - val_loss: 0.3298 - val_mae: 0.4726
# Epoch 35/50
# 44/44 - 0s - 8ms/step - loss: 0.4061 - mae: 0.5126 - val_loss: 0.3152 - val_mae: 0.4650
# Epoch 36/50
# 44/44 - 0s - 7ms/step - loss: 0.3978 - mae: 0.5052 - val_loss: 0.3015 - val_mae: 0.4599
# Epoch 37/50
# 44/44 - 0s - 4ms/step - loss: 0.3868 - mae: 0.4921 - val_loss: 0.2987 - val_mae: 0.4632
# Epoch 38/50
# 44/44 - 0s - 7ms/step - loss: 0.3785 - mae: 0.4902 - val_loss: 0.2867 - val_mae: 0.4472
# Epoch 39/50
# 44/44 - 0s - 5ms/step - loss: 0.3762 - mae: 0.4943 - val_loss: 0.2987 - val_mae: 0.4442
# Epoch 40/50
# 44/44 - 0s - 5ms/step - loss: 0.3596 - mae: 0.4759 - val_loss: 0.2927 - val_mae: 0.4411
# Epoch 41/50
# 44/44 - 0s - 7ms/step - loss: 0.3573 - mae: 0.4765 - val_loss: 0.2672 - val_mae: 0.4357
# Epoch 42/50
# 44/44 - 0s - 4ms/step - loss: 0.3442 - mae: 0.4669 - val_loss: 0.2667 - val_mae: 0.4340
# Epoch 43/50
# 44/44 - 0s - 6ms/step - loss: 0.3401 - mae: 0.4650 - val_loss: 0.2627 - val_mae: 0.4176
# Epoch 44/50
# 44/44 - 0s - 3ms/step - loss: 0.3353 - mae: 0.4538 - val_loss: 0.2582 - val_mae: 0.4154
# Epoch 45/50
# 44/44 - 0s - 3ms/step - loss: 0.3255 - mae: 0.4550 - val_loss: 0.2498 - val_mae: 0.4083
# Epoch 46/50
# 44/44 - 0s - 3ms/step - loss: 0.3208 - mae: 0.4512 - val_loss: 0.2416 - val_mae: 0.4049
# Epoch 47/50
# 44/44 - 0s - 3ms/step - loss: 0.3166 - mae: 0.4433 - val_loss: 0.2390 - val_mae: 0.3990
# Epoch 48/50
# 44/44 - 0s - 3ms/step - loss: 0.3096 - mae: 0.4385 - val_loss: 0.2321 - val_mae: 0.4000
# Epoch 49/50
# 44/44 - 0s - 8ms/step - loss: 0.3014 - mae: 0.4376 - val_loss: 0.2265 - val_mae: 0.3890
# Epoch 50/50
# 44/44 - 0s - 5ms/step - loss: 0.2939 - mae: 0.4285 - val_loss: 0.2231 - val_mae: 0.3851
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step

# %% [markdown]
# Végül megjelenítjük a predikciót és az eredeti értékeket.

# %%
plt.figure(figsize=(12,8))
plt.plot(preds, color='r', label="Predictions")
plt.plot(targets, color='g', label="Targets")
plt.legend()
